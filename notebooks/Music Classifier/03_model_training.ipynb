# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.calibration import CalibratedClassifierCV
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Cargar los datos
df = pd.read_csv("../../data/songs/audio_features_15s.csv")

# %%
# 2. Separar Features (X), Target (y) y Grupos (song_id)
X = df.drop(columns=['label', 'song_id', 'segment_type'])
y = df['label']
groups = df['song_id']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
# 3. GroupShuffleSplit — mismo random_state que v1 para comparación justa
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=9347234)
train_idx, test_idx = next(gss.split(X, y_encoded, groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

# %%
# 4. Estandarización
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# # 1er Run de Modelos

# %%
# 5. Definir modelos
# ─── Modelos originales ───────────────────────────────────────────────────────
svm_rbf  = SVC(kernel='rbf',    probability=True, random_state=42)
rf       = RandomForestClassifier(n_estimators=100, random_state=42)
gb       = GradientBoostingClassifier(n_estimators=100, random_state=42)

# ─── Nuevos kernels SVM ───────────────────────────────────────────────────────
# Linear: separa con una línea recta, más rápido, mejor en espacios de alta dimensión
svm_linear = SVC(kernel='linear', probability=True, random_state=42)

# Poly: captura interacciones entre features (ej. tempo × chroma)
# degree=3 es el estándar, C=1 regularización por defecto
svm_poly   = SVC(kernel='poly', degree=3, probability=True, random_state=42)

# LinearSVC: versión optimizada del kernel lineal, mucho más rápida en datasets grandes
# Necesita CalibratedClassifierCV para obtener probabilidades
linear_svc = CalibratedClassifierCV(LinearSVC(random_state=42, max_iter=2000))

# ─── Voting Classifier (combinación de los mejores) ──────────────────────────
# Combina SVM-Linear + GB + RF: vota por mayoría suave (soft = usa probabilidades)
voting = VotingClassifier(
    estimators=[
        ('svm_linear', SVC(kernel='linear', probability=True, random_state=42)),
        ('gb',         GradientBoostingClassifier(n_estimators=100, random_state=42)),
        ('rf',         RandomForestClassifier(n_estimators=100, random_state=42))
    ],
    voting='soft'
)

models = {
    # Originales
    "SVM (RBF)": svm_rbf,
    "Random Forest": rf,
    "Gradient Boosting": gb,
    # Nuevos
    "SVM (Linear)": svm_linear,
    "SVM (Poly)": svm_poly,
    "LinearSVC": linear_svc,
    "Voting (Linear + GB + RF)": voting
}

# %%
# 6. Entrenamiento, evaluación y comparación
resultados = []  # Para tabla comparativa al final

for name, model in models.items():
    print(f"\n{'='*55}")
    print(f"  Entrenando: {name}")
    print(f"{'='*55}")

    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    acc = accuracy_score(y_test, y_pred)
    print(f"Exactitud (Accuracy) Global: {acc:.4f}\n")
    print("Reporte de Clasificación:")
    print(classification_report(y_test, y_pred, target_names=le.classes_))

    # Guardar para tabla final
    from sklearn.metrics import f1_score
    macro_f1 = f1_score(y_test, y_pred, average='macro')
    resultados.append({'Modelo': name, 'Accuracy': round(acc, 4), 'Macro F1': round(macro_f1, 4)})

    # Matriz de confusión
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=le.classes_, yticklabels=le.classes_)
    plt.title(f'Matriz de Confusión — {name}')
    plt.ylabel('Etiqueta Real')
    plt.xlabel('Predicción')
    plt.tight_layout()
    plt.show()
# Out:
# =======================================================
#   Entrenando: SVM (RBF)
# =======================================================
# Exactitud (Accuracy) Global: 0.7196
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.59      0.66      0.62       155
#      Hip-Hop       0.71      0.64      0.67        98
#         Rock       0.58      0.66      0.62        86
#    Vallenato       0.88      0.78      0.82       129
#      clasicc       0.95      0.96      0.95       149
#         jazz       0.85      0.86      0.85       177
#          pop       0.48      0.44      0.46       169
#
#     accuracy                           0.72       963
#    macro avg       0.72      0.72      0.72       963
# weighted avg       0.72      0.72      0.72       963
# =======================================================
#   Entrenando: Random Forest
# =======================================================
# Exactitud (Accuracy) Global: 0.6906
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.65      0.66      0.65       155
#      Hip-Hop       0.59      0.61      0.60        98
#         Rock       0.57      0.79      0.66        86
#    Vallenato       0.78      0.73      0.76       129
#      clasicc       0.97      0.94      0.95       149
#         jazz       0.76      0.81      0.79       177
#          pop       0.44      0.34      0.38       169
#
#     accuracy                           0.69       963
#    macro avg       0.68      0.70      0.68       963
# weighted avg       0.69      0.69      0.69       963
# =======================================================
#   Entrenando: Gradient Boosting
# =======================================================
# Exactitud (Accuracy) Global: 0.7061
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.69      0.63      0.66       155
#      Hip-Hop       0.64      0.66      0.65        98
#         Rock       0.60      0.81      0.69        86
#    Vallenato       0.83      0.78      0.80       129
#      clasicc       0.97      0.93      0.95       149
#         jazz       0.79      0.75      0.77       177
#          pop       0.44      0.45      0.45       169
#
#     accuracy                           0.71       963
#    macro avg       0.71      0.72      0.71       963
# weighted avg       0.71      0.71      0.71       963
# =======================================================
#   Entrenando: SVM (Linear)
# =======================================================
# Exactitud (Accuracy) Global: 0.6791
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.53      0.54      0.53       155
#      Hip-Hop       0.55      0.64      0.59        98
#         Rock       0.50      0.60      0.55        86
#    Vallenato       0.91      0.78      0.84       129
#      clasicc       0.95      0.86      0.90       149
#         jazz       0.82      0.79      0.80       177
#          pop       0.51      0.52      0.52       169
#
#     accuracy                           0.68       963
#    macro avg       0.68      0.68      0.68       963
# weighted avg       0.69      0.68      0.69       963
# =======================================================
#   Entrenando: SVM (Poly)
# =======================================================
# Exactitud (Accuracy) Global: 0.6355
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.65      0.46      0.54       155
#      Hip-Hop       0.69      0.61      0.65        98
#         Rock       0.37      0.83      0.51        86
#    Vallenato       0.50      0.89      0.64       129
#      clasicc       0.99      0.87      0.92       149
#         jazz       0.86      0.72      0.78       177
#          pop       0.59      0.22      0.33       169
#
#     accuracy                           0.64       963
#    macro avg       0.66      0.66      0.62       963
# weighted avg       0.69      0.64      0.63       963
# =======================================================
#   Entrenando: LinearSVC
# =======================================================
# Exactitud (Accuracy) Global: 0.6771
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.57      0.50      0.53       155
#      Hip-Hop       0.54      0.57      0.56        98
#         Rock       0.51      0.72      0.60        86
#    Vallenato       0.78      0.70      0.73       129
#      clasicc       0.93      0.91      0.92       149
#         jazz       0.80      0.84      0.82       177
#          pop       0.53      0.49      0.51       169
#
#     accuracy                           0.68       963
#    macro avg       0.67      0.68      0.67       963
# weighted avg       0.68      0.68      0.68       963
# =======================================================
#   Entrenando: Voting (Linear + GB + RF)
# =======================================================
# Exactitud (Accuracy) Global: 0.7352
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.66      0.65      0.66       155
#      Hip-Hop       0.68      0.70      0.69        98
#         Rock       0.65      0.79      0.72        86
#    Vallenato       0.87      0.80      0.83       129
#      clasicc       0.97      0.93      0.95       149
#         jazz       0.80      0.83      0.81       177
#          pop       0.51      0.48      0.49       169
#
#     accuracy                           0.74       963
#    macro avg       0.73      0.74      0.74       963
# weighted avg       0.74      0.74      0.73       963

# %%
# 7. Tabla comparativa final de todos los modelos
df_resultados = pd.DataFrame(resultados).sort_values('Macro F1', ascending=False)
df_resultados = df_resultados.reset_index(drop=True)
df_resultados.index += 1  # Ranking desde 1

print("\n" + "="*50)
print("       RANKING FINAL DE MODELOS")
print("="*50)
print(df_resultados.to_string())
print("="*50)
print("\nMejor modelo por Macro F1:", df_resultados.iloc[0]['Modelo'])
# Out:
# ==================================================
#        RANKING FINAL DE MODELOS
# ==================================================
#                       Modelo  Accuracy  Macro F1
# 1  Voting (Linear + GB + RF)    0.7352    0.7366
# 2                  SVM (RBF)    0.7196    0.7151
# 3          Gradient Boosting    0.7061    0.7099
# 4              Random Forest    0.6906    0.6844
# 5               SVM (Linear)    0.6791    0.6763
# 6                  LinearSVC    0.6771    0.6671
# 7                 SVM (Poly)    0.6355    0.6246
# ==================================================
#
# Mejor modelo por Macro F1: Voting (Linear + GB + RF)

# %% [markdown]
# # 2do Run de Modelos

# %% [markdown]
# Se ve que el mejor modelo es el ensemble "voting":
#
# 1. En el Rock & Pop es donde el modelo esta realmente sufriendo ya que el Rock tiene muy baja precision en 0.37 y muy alto el recall 0.9 lo que nos da a entender que muy probablemente el modelo lo que está haciendo es que lo que no entiende como una clase muy claramente lo manda a rock haciendo que meta rock donde va pero tambien cuando no es y en el Pop sucede que ni la presicion, ni el f1 ni el recall son buenos lo cual puede que suceda porque el pop es un genero que comparte caracteristicas con los demas al tiempo

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Reducimos a 2 dimensiones para poder graficar
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train_scaled)

# 2. Creamos un DataFrame para graficar con Seaborn
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['Género'] = le.inverse_transform(y_train)

# 3. Graficamos
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='Género', alpha=0.7, palette='bright')
plt.title('Mapa de Géneros: ¿Por qué fallan Rock y Pop?')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# OPCIÓN A — LDA: la mejor para ver separación real entre clases
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit_transform(X_train_scaled, y_train)  # usa las etiquetas ← clave

df_lda = pd.DataFrame(X_lda, columns=['LD1', 'LD2'])
df_lda['Género'] = le.inverse_transform(y_train)

plt.figure(figsize=(10, 7))
sns.scatterplot(data=df_lda, x='LD1', y='LD2', hue='Género', alpha=0.7, palette='bright')
plt.title('LDA — Separación real entre géneros')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Vemos que Pop & Rock comparten un gran campo de las caracteristicas por lo que muy probablemente lo que esta sucediendo es que no se diferencian del todo bien,necesitamos o otras caracteristicas o mas datos o algo mas que nos haga realmente diferenciar estos 2 de los demas y entre si. **El punto es mejorar la frontera de decision**

# %%
df['label'].value_counts()
# Out:
# label
# clasicc        746
# Vallenato      729
# jazz           706
# Electronica    705
# Rock           679
# pop            670
# Hip-Hop        550
# Name: count, dtype: int64

# %% [markdown]
# Para eso nos podría servir el **SMOTE (Synthetic Minority Over-sampling Technique)** o
#
# ## **SMOTE**
#
# Aunque el Rock y el Pop tengan casi 150 muestras, sus "puntos" en el espacio matemático pueden estar muy dispersos o rodeados de mucho "ruido" de otros géneros.
#
# 1. SMOTE no se usa solo para cuando hay "poquitos" datos, sino para densificar las zonas donde el modelo duda. Al crear puntos intermedios entre los datos reales de Rock, estamos rellenando los huecos vacíos en el mapa.
#
# 2. Al haber más puntos de Rock y Pop concentrados en sus áreas, los algoritmos como el SVM o el Voting Classifier pueden trazar una "línea de frontera" mucho más precisa y menos zigzagueante.
#
# 3. Ayuda a que el modelo no se aprenda de memoria una canción de Rock específica (Overfitting), sino que entienda la "región" donde suele vivir el sonido del Rock.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

X = df.drop(columns=['label', 'song_id', 'segment_type'])
y = df['label']
groups = df['song_id']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# GroupShuffleSplit (Mantenemos el random_state para que el TEST sea el mismo de antes)
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=9347234)
train_idx, test_idx = next(gss.split(X, y_encoded, groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

# Estandarización
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# ─── NUEVO PASO: APLICACIÓN DE SMOTE ─────────────────────────────────────────
# Explicación para clase: Balanceamos el Hip-Hop y densificamos Rock/Pop
print(f"Antes de SMOTE: {Counter(y_train)}")

smote = SMOTE(random_state=42, k_neighbors=5)
X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

print(f"Después de SMOTE: {Counter(y_train_res)}")
# ─────────────────────────────────────────────────────────────────────────────

# Definir modelos (Incluyendo los pesos balanceados para mayor robustez)
models = {
    "SVM (RBF)": SVC(kernel='rbf', probability=True, class_weight='balanced', random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "SVM (Linear)": SVC(kernel='linear', probability=True, class_weight='balanced', random_state=42),
    "Voting (Linear + GB + RF)": VotingClassifier(
        estimators=[
            ('svm_linear', SVC(kernel='linear', probability=True, class_weight='balanced', random_state=42)),
            ('gb',         GradientBoostingClassifier(n_estimators=100, random_state=42)),
            ('rf',         RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42))
        ],
        voting='soft'
    )
}

# Entrenamiento, evaluación y comparación
resultados_smote = []

for name, model in models.items():
    print(f"\n{'='*55}")
    print(f"  Entrenando con SMOTE: {name}")
    print(f"{'='*55}")

    # IMPORTANTE: Entrenamos con los datos aumentados (res), evaluamos con test REAL
    model.fit(X_train_res, y_train_res)
    y_pred = model.predict(X_test_scaled)

    acc = accuracy_score(y_test, y_pred)
    macro_f1 = f1_score(y_test, y_pred, average='macro')

    print(f"Exactitud (Accuracy): {acc:.4f}")
    print(f"Macro F1-Score: {macro_f1:.4f}\n")
    print(classification_report(y_test, y_pred, target_names=le.classes_))

    resultados_smote.append({'Modelo': name, 'Accuracy': round(acc, 4), 'Macro F1': round(macro_f1, 4)})

    # Matriz de Confusión
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', # Color verde para diferenciarlo
                xticklabels=le.classes_, yticklabels=le.classes_)
    plt.title(f'Matriz Confusión (SMOTE) — {name}')
    plt.show()
# Out:
# Antes de SMOTE: Counter({np.int64(3): 600, np.int64(4): 597, np.int64(2): 593, np.int64(0): 550, np.int64(5): 529, np.int64(6): 501, np.int64(1): 452})
# Después de SMOTE: Counter({np.int64(4): 600, np.int64(0): 600, np.int64(1): 600, np.int64(5): 600, np.int64(6): 600, np.int64(2): 600, np.int64(3): 600})
#
# =======================================================
#   Entrenando con SMOTE: SVM (RBF)
# =======================================================
# Exactitud (Accuracy): 0.7165
# Macro F1-Score: 0.7123
#
#               precision    recall  f1-score   support
#
#  Electronica       0.58      0.65      0.61       155
#      Hip-Hop       0.70      0.64      0.67        98
#         Rock       0.58      0.64      0.61        86
#    Vallenato       0.89      0.78      0.83       129
#      clasicc       0.94      0.96      0.95       149
#         jazz       0.84      0.86      0.85       177
#          pop       0.48      0.46      0.47       169
#
#     accuracy                           0.72       963
#    macro avg       0.72      0.71      0.71       963
# weighted avg       0.72      0.72      0.72       963
# =======================================================
#   Entrenando con SMOTE: Random Forest
# =======================================================
# Exactitud (Accuracy): 0.6833
# Macro F1-Score: 0.6769
#
#               precision    recall  f1-score   support
#
#  Electronica       0.65      0.66      0.66       155
#      Hip-Hop       0.53      0.53      0.53        98
#         Rock       0.60      0.76      0.67        86
#    Vallenato       0.80      0.71      0.75       129
#      clasicc       0.98      0.95      0.97       149
#         jazz       0.75      0.81      0.78       177
#          pop       0.41      0.36      0.38       169
#
#     accuracy                           0.68       963
#    macro avg       0.67      0.68      0.68       963
# weighted avg       0.68      0.68      0.68       963
# =======================================================
#   Entrenando con SMOTE: Gradient Boosting
# =======================================================
# Exactitud (Accuracy): 0.6874
# Macro F1-Score: 0.6897
#
#               precision    recall  f1-score   support
#
#  Electronica       0.71      0.63      0.66       155
#      Hip-Hop       0.56      0.64      0.60        98
#         Rock       0.60      0.79      0.68        86
#    Vallenato       0.82      0.67      0.74       129
#      clasicc       0.97      0.93      0.95       149
#         jazz       0.76      0.75      0.75       177
#          pop       0.43      0.46      0.44       169
#
#     accuracy                           0.69       963
#    macro avg       0.69      0.69      0.69       963
# weighted avg       0.70      0.69      0.69       963
# =======================================================
#   Entrenando con SMOTE: SVM (Linear)
# =======================================================
# Exactitud (Accuracy): 0.6729
# Macro F1-Score: 0.6717
#
#               precision    recall  f1-score   support
#
#  Electronica       0.52      0.48      0.50       155
#      Hip-Hop       0.54      0.65      0.59        98
#         Rock       0.53      0.60      0.56        86
#    Vallenato       0.91      0.78      0.84       129
#      clasicc       0.95      0.87      0.91       149
#         jazz       0.82      0.78      0.80       177
#          pop       0.48      0.53      0.50       169
#
#     accuracy                           0.67       963
#    macro avg       0.68      0.67      0.67       963
# weighted avg       0.69      0.67      0.68       963
# =======================================================
#   Entrenando con SMOTE: Voting (Linear + GB + RF)
# =======================================================
# Exactitud (Accuracy): 0.7300
# Macro F1-Score: 0.7317
#
#               precision    recall  f1-score   support
#
#  Electronica       0.66      0.65      0.66       155
#      Hip-Hop       0.65      0.70      0.68        98
#         Rock       0.66      0.73      0.70        86
#    Vallenato       0.89      0.76      0.82       129
#      clasicc       0.98      0.93      0.96       149
#         jazz       0.79      0.82      0.81       177
#          pop       0.50      0.51      0.51       169
#
#     accuracy                           0.73       963
#    macro avg       0.73      0.73      0.73       963
# weighted avg       0.74      0.73      0.73       963

# %% [markdown]
# Realmente no mejoró mucho asi que veamos cuales son las features que realmente mas estan importando

# %% [markdown]
# ## FE

# %%
# 1. Entrenamos el Random Forest con los datos de SMOTE
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_model.fit(X_train_res, y_train_res)

# 2. Obtenemos la importancia y la organizamos
importances = rf_model.feature_importances_
feature_names = X.columns
indices = np.argsort(importances)[-15:]  # Tomamos las 15 más importantes

# 3. Graficamos
plt.figure(figsize=(10, 8))
plt.title('Top 15 Características más importantes (¿Qué diferencia los géneros?)')
plt.barh(range(len(indices)), importances[indices], color='purple', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Importancia Relativa')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['tempo', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
#        'zero_crossing_rate', 'rms', 'chroma_stft', 'onset_strength_mean',
#        'onset_strength_std', 'pitch_variance', 'spectral_flux_std',
#        'mfcc1_mean', 'mfcc1_std', 'mfcc2_mean', 'mfcc2_std', 'mfcc3_mean',
#        'mfcc3_std', 'mfcc4_mean', 'mfcc4_std', 'mfcc5_mean', 'mfcc5_std',
#        'mfcc6_mean', 'mfcc6_std', 'mfcc7_mean', 'mfcc7_std', 'mfcc8_mean',
#        'mfcc8_std', 'mfcc9_mean', 'mfcc9_std', 'mfcc10_mean', 'mfcc10_std',
#        'mfcc11_mean', 'mfcc11_std', 'mfcc12_mean', 'mfcc12_std', 'mfcc13_mean',
#        'mfcc13_std', 'harm_perc_ratio', 'spectral_flatness_mean',
#        'tonnetz_0_std', 'tonnetz_1_std', 'tonnetz_2_std', 'tonnetz_3_std',
#        'tonnetz_4_std', 'tonnetz_5_std', 'tempo_cv', 'bass_ratio', 'label',
#        'song_id', 'segment_type'],
#       dtype='str')

# %% [markdown]
# Algo que llama la atencion es que el **"spectral rolloff"** *(es la frecuencia por debajo de la cual se encuentra el 85% de la energía del espectro. Básicamente, te dice qué tan "brillante" o "agudo" es un sonido.)* que es una de las metricas mas importantes en el paper no para diferenciar al rock no aparece ni si quiera en las 15 mas importantes lo que nos da un indicio de que existe un **solapamiento de brillo** ya que el Pop moderno está tan producido y tiene tantos sintetizadores agudos que su "brillo" (rolloff) es matemáticamente casi igual al de una guitarra distorsionada de Rock. Veamos que tan parecido son estos 2 para Rock y Pop para *verificar la hipotesis*

# %%
plt.figure(figsize=(8,5))
subset = df[df['label'].isin(['Rock', 'pop'])]
sns.kdeplot(data=subset, x='rolloff', hue='label', fill=True)
plt.title('Distribución de Rolloff: Rock vs Pop')
plt.show()

# %% [markdown]
# Viendo que claramente la hipotesis es cierta porque vemos que hay un solapamiento fuertisimo entre las 2 que confunde al modelo, algo que podriamos hacer es hacer que el modelo vea otra forma de relacionar el brillo para que capte la diferencia, lo cual lo podemos hacer creando una nueva feature

# %%
df['brightness_ratio'] = df['rolloff'] / (df['spectral_centroid'] + 1e-6)

# %%
plt.figure(figsize=(10, 6))
# Filtramos solo Rock y Pop para ver el duelo directo
subset = df[df['label'].isin(['Rock', 'pop'])]

sns.kdeplot(data=subset, x='brightness_ratio', hue='label', fill=True, common_norm=False, palette='Set1')
plt.title('Diferencia de "Pureza de Brillo" (brightness_ratio): Rock vs Pop')
plt.xlabel('Relación Rolloff / Spectral Centroid')
plt.ylabel('Densidad')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# Ni aun asi vemos que se quita el solapamiento, de hecho asi es aún peor, por lo que otra cosa que podríamos hacer es quitar el ruido de otras features que no tengan importancia o no esten importando tanto y ver si mejora veamos...

# %%
# Suponiendo que ya tienes el rf_model entrenado
importances = rf_model.feature_importances_
feature_names = X.columns
# Ordenamos de menor a mayor
indices_bajos = np.argsort(importances)[:7]

print("Variables con MENOR importancia (Candidatas a ser eliminadas):")
for i in indices_bajos:
    print(f"- {feature_names[i]}: {importances[i]:.4f}")
# Out:
# Variables con MENOR importancia (Candidatas a ser eliminadas):
# - mfcc9_std: 0.0095
# - mfcc10_std: 0.0098
# - mfcc1_std: 0.0098
# - mfcc12_mean: 0.0107
# - mfcc12_std: 0.0116
# - mfcc11_std: 0.0121
# - mfcc11_mean: 0.0122

# %% [markdown]
# ## Optuna+SMOTE+FE

# %%
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import cross_val_score

# --- CONFIGURACIÓN DE OPTUNA MEJORADA ---

def objective(trial):
    # 1. SVC (RBF) - Rango de búsqueda más amplio
    svc_rbf_c = trial.suggest_float("svc_rbf_c", 0.01, 200, log=True)
    svc_rbf_gamma = trial.suggest_float("svc_rbf_gamma", 1e-4, 1.0, log=True)

    # 2. Random Forest - Con regularización (min_samples_split)
    rf_n_estimators = trial.suggest_int("rf_n_estimators", 200, 700)
    rf_max_depth = trial.suggest_int("rf_max_depth", 10, 80)
    rf_min_samples_split = trial.suggest_int("rf_min_samples_split", 2, 10)

    # 3. Gradient Boosting - Con subsample para mayor robustez
    gb_learning_rate = trial.suggest_float("gb_learning_rate", 0.005, 0.2, log=True)
    gb_n_estimators = trial.suggest_int("gb_n_estimators", 100, 400)
    gb_subsample = trial.suggest_float("gb_subsample", 0.6, 1.0)

    # Definimos el Voting Classifier
    # Pesos: Le damos mayor importancia al Gradient Boosting (2) que es más flexible
    clf = VotingClassifier(
        estimators=[
            ('svm_linear', SVC(kernel='linear', C=1.0, probability=True, class_weight='balanced', random_state=42)),
            ('svm_rbf',    SVC(kernel='rbf', C=svc_rbf_c, gamma=svc_rbf_gamma, probability=True, class_weight='balanced', random_state=42)),
            ('rf',         RandomForestClassifier(n_estimators=rf_n_estimators, max_depth=rf_max_depth, min_samples_split=rf_min_samples_split, class_weight='balanced', random_state=42)),
            ('gb',         GradientBoostingClassifier(n_estimators=gb_n_estimators, learning_rate=gb_learning_rate, subsample=gb_subsample, random_state=42))
        ],
        voting='soft',
        weights=[1, 1, 1, 2] 
    )

    score = cross_val_score(clf, X_train_res, y_train_res, n_jobs=-1, cv=3, scoring='f1_macro')
    return score.mean()

# 4. EJECUCIÓN DE LA OPTIMIZACIÓN
print("Iniciando optimización avanzada con 100 trials...")

# Usamos TPESampler con un arranque aleatorio para mejor exploración
sampler = TPESampler(n_startup_trials=20) 
study = optuna.create_study(direction="maximize", sampler=sampler)

# Aumentamos n_trials a 100
study.optimize(objective, n_trials=100) 

print("\n" + "="*30)
print("  MEJORES PARÁMETROS ENCONTRADOS")
print("="*30)
print(study.best_params)

# 5. ENTRENAMIENTO DEL MODELO FINAL
best = study.best_params

voting_final_opt = VotingClassifier(
    estimators=[
        ('svm_linear', SVC(kernel='linear', C=1.0, probability=True, class_weight='balanced', random_state=42)),
        ('svm_rbf',    SVC(kernel='rbf', C=best['svc_rbf_c'], gamma=best['svc_rbf_gamma'], probability=True, class_weight='balanced', random_state=42)),
        ('rf',         RandomForestClassifier(n_estimators=best['rf_n_estimators'], max_depth=best['rf_max_depth'], min_samples_split=best['rf_min_samples_split'], class_weight='balanced', random_state=42)),
        ('gb',         GradientBoostingClassifier(n_estimators=best['gb_n_estimators'], learning_rate=best['gb_learning_rate'], subsample=best['gb_subsample'], random_state=42))
    ],
    voting='soft',
    weights=[1, 1, 1, 2]
)

voting_final_opt.fit(X_train_res, y_train_res)
# Out:
# [I 2026-05-21 12:31:05,140] A new study created in memory with name: no-name-556d144e-8d60-409b-93b8-d359c238caae
# Iniciando optimización avanzada con 100 trials...
# [I 2026-05-21 12:31:47,299] Trial 0 finished with value: 0.8083239505967271 and parameters: {'svc_rbf_c': 0.11080875070755383, 'svc_rbf_gamma': 0.00018141113020191148, 'rf_n_estimators': 271, 'rf_max_depth': 67, 'rf_min_samples_split': 2, 'gb_learning_rate': 0.02502858413570796, 'gb_n_estimators': 351, 'gb_subsample': 0.602864412425339}. Best is trial 0 with value: 0.8083239505967271.
# [I 2026-05-21 12:32:17,751] Trial 1 finished with value: 0.8277636269913069 and parameters: {'svc_rbf_c': 19.179094023275777, 'svc_rbf_gamma': 0.11475608081806722, 'rf_n_estimators': 594, 'rf_max_depth': 74, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.18262200662119263, 'gb_n_estimators': 177, 'gb_subsample': 0.7374043085891652}. Best is trial 1 with value: 0.8277636269913069.
# [I 2026-05-21 12:32:41,142] Trial 2 finished with value: 0.8293928794482076 and parameters: {'svc_rbf_c': 23.58825876704425, 'svc_rbf_gamma': 0.06878051199995226, 'rf_n_estimators': 407, 'rf_max_depth': 47, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.12077646424482401, 'gb_n_estimators': 112, 'gb_subsample': 0.8832013424032936}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:33:29,268] Trial 3 finished with value: 0.7933452827055146 and parameters: {'svc_rbf_c': 19.133931365018277, 'svc_rbf_gamma': 0.0009218120650692977, 'rf_n_estimators': 336, 'rf_max_depth': 33, 'rf_min_samples_split': 3, 'gb_learning_rate': 0.007386549761342046, 'gb_n_estimators': 394, 'gb_subsample': 0.6445090383304296}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:34:26,466] Trial 4 finished with value: 0.7924676614148765 and parameters: {'svc_rbf_c': 0.20060549772288067, 'svc_rbf_gamma': 0.04544684480627375, 'rf_n_estimators': 371, 'rf_max_depth': 77, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.015271132191259902, 'gb_n_estimators': 379, 'gb_subsample': 0.793768734749255}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:35:21,758] Trial 5 finished with value: 0.822227532329353 and parameters: {'svc_rbf_c': 2.6619483126362935, 'svc_rbf_gamma': 0.0032837639786713014, 'rf_n_estimators': 654, 'rf_max_depth': 51, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.08851532581276803, 'gb_n_estimators': 328, 'gb_subsample': 0.8585598442629012}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:35:49,636] Trial 6 finished with value: 0.822844064927958 and parameters: {'svc_rbf_c': 2.8111475844660707, 'svc_rbf_gamma': 0.036935256090798826, 'rf_n_estimators': 695, 'rf_max_depth': 55, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.04142752266612962, 'gb_n_estimators': 172, 'gb_subsample': 0.7190949860782363}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:36:48,532] Trial 7 finished with value: 0.818755116753399 and parameters: {'svc_rbf_c': 0.034206284005062225, 'svc_rbf_gamma': 0.0014262738551765262, 'rf_n_estimators': 616, 'rf_max_depth': 69, 'rf_min_samples_split': 4, 'gb_learning_rate': 0.1273459943184034, 'gb_n_estimators': 344, 'gb_subsample': 0.8320991953106672}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:37:08,287] Trial 8 finished with value: 0.7767162205135415 and parameters: {'svc_rbf_c': 15.578804610225246, 'svc_rbf_gamma': 0.00010752846860061773, 'rf_n_estimators': 529, 'rf_max_depth': 74, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.00536653664857466, 'gb_n_estimators': 124, 'gb_subsample': 0.6759182350953116}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:37:56,914] Trial 9 finished with value: 0.7722620338666992 and parameters: {'svc_rbf_c': 4.374664238453711, 'svc_rbf_gamma': 0.0001336783826490293, 'rf_n_estimators': 589, 'rf_max_depth': 46, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.0069752946236820036, 'gb_n_estimators': 280, 'gb_subsample': 0.8809613051339907}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:38:31,316] Trial 10 finished with value: 0.8147310318037997 and parameters: {'svc_rbf_c': 0.01360843174756369, 'svc_rbf_gamma': 0.034257253100827015, 'rf_n_estimators': 526, 'rf_max_depth': 11, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.12281606181053821, 'gb_n_estimators': 259, 'gb_subsample': 0.6381352963268688}. Best is trial 2 with value: 0.8293928794482076.
# [I 2026-05-21 12:39:32,219] Trial 11 finished with value: 0.8318486783410695 and parameters: {'svc_rbf_c': 10.964184608462784, 'svc_rbf_gamma': 0.02086978652601627, 'rf_n_estimators': 699, 'rf_max_depth': 69, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.04053852305382759, 'gb_n_estimators': 373, 'gb_subsample': 0.7963700985269837}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:39:52,658] Trial 12 finished with value: 0.8148597080246116 and parameters: {'svc_rbf_c': 7.731759277546986, 'svc_rbf_gamma': 0.00141784457956199, 'rf_n_estimators': 612, 'rf_max_depth': 71, 'rf_min_samples_split': 10, 'gb_learning_rate': 0.14552054817507265, 'gb_n_estimators': 105, 'gb_subsample': 0.788205214149628}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:40:23,787] Trial 13 finished with value: 0.8220820961671024 and parameters: {'svc_rbf_c': 30.778595681977713, 'svc_rbf_gamma': 0.017591987930151175, 'rf_n_estimators': 619, 'rf_max_depth': 46, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.006676505731330933, 'gb_n_estimators': 232, 'gb_subsample': 0.6406991356036928}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:41:14,360] Trial 14 finished with value: 0.8179292202876813 and parameters: {'svc_rbf_c': 5.780127944119648, 'svc_rbf_gamma': 0.24600279338199985, 'rf_n_estimators': 451, 'rf_max_depth': 27, 'rf_min_samples_split': 4, 'gb_learning_rate': 0.013902964115124011, 'gb_n_estimators': 264, 'gb_subsample': 0.970214307962192}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:41:59,393] Trial 15 finished with value: 0.8227170751510905 and parameters: {'svc_rbf_c': 0.03328851461810125, 'svc_rbf_gamma': 0.004775401633837351, 'rf_n_estimators': 578, 'rf_max_depth': 48, 'rf_min_samples_split': 2, 'gb_learning_rate': 0.1789540183685934, 'gb_n_estimators': 253, 'gb_subsample': 0.854915351854256}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:43:03,418] Trial 16 finished with value: 0.8083819744649855 and parameters: {'svc_rbf_c': 2.0474532935136227, 'svc_rbf_gamma': 0.027640410760238973, 'rf_n_estimators': 449, 'rf_max_depth': 64, 'rf_min_samples_split': 10, 'gb_learning_rate': 0.008530944299334634, 'gb_n_estimators': 330, 'gb_subsample': 0.9859680912800384}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:43:22,234] Trial 17 finished with value: 0.7999857717380694 and parameters: {'svc_rbf_c': 0.01783748705759488, 'svc_rbf_gamma': 0.041203210131934925, 'rf_n_estimators': 485, 'rf_max_depth': 37, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.1450973537538293, 'gb_n_estimators': 101, 'gb_subsample': 0.7346709298895948}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:43:45,699] Trial 18 finished with value: 0.8269965862751675 and parameters: {'svc_rbf_c': 42.694052264791, 'svc_rbf_gamma': 0.02616711261337554, 'rf_n_estimators': 649, 'rf_max_depth': 79, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.007250786962767955, 'gb_n_estimators': 162, 'gb_subsample': 0.6277927987092242}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:44:20,290] Trial 19 finished with value: 0.7953659459988222 and parameters: {'svc_rbf_c': 10.671742992282608, 'svc_rbf_gamma': 0.0004321704934390805, 'rf_n_estimators': 598, 'rf_max_depth': 56, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.017929984912936767, 'gb_n_estimators': 268, 'gb_subsample': 0.6327053143412155}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:44:58,086] Trial 20 finished with value: 0.8254041917392585 and parameters: {'svc_rbf_c': 168.48451581621316, 'svc_rbf_gamma': 0.5012393583146691, 'rf_n_estimators': 207, 'rf_max_depth': 61, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.05818312233583607, 'gb_n_estimators': 208, 'gb_subsample': 0.9186090683230552}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:45:21,684] Trial 21 finished with value: 0.829757867835912 and parameters: {'svc_rbf_c': 96.584307446692, 'svc_rbf_gamma': 0.13927583744087602, 'rf_n_estimators': 397, 'rf_max_depth': 61, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.07302876051649991, 'gb_n_estimators': 141, 'gb_subsample': 0.7477219055177861}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:45:47,112] Trial 22 finished with value: 0.8169416867487355 and parameters: {'svc_rbf_c': 89.31821815253147, 'svc_rbf_gamma': 0.9531362464318888, 'rf_n_estimators': 368, 'rf_max_depth': 58, 'rf_min_samples_split': 4, 'gb_learning_rate': 0.07410643135780709, 'gb_n_estimators': 144, 'gb_subsample': 0.7709936838054228}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:46:26,706] Trial 23 finished with value: 0.8220602444627764 and parameters: {'svc_rbf_c': 0.6750189405418328, 'svc_rbf_gamma': 0.13450861783191623, 'rf_n_estimators': 408, 'rf_max_depth': 38, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.03953833237845488, 'gb_n_estimators': 206, 'gb_subsample': 0.9214137835126535}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:46:50,284] Trial 24 finished with value: 0.8301708068379895 and parameters: {'svc_rbf_c': 75.40070056049686, 'svc_rbf_gamma': 0.09611694975495294, 'rf_n_estimators': 302, 'rf_max_depth': 63, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.05283644813997042, 'gb_n_estimators': 134, 'gb_subsample': 0.8205709640728086}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:47:34,696] Trial 25 finished with value: 0.8312301816401194 and parameters: {'svc_rbf_c': 68.78026643257877, 'svc_rbf_gamma': 0.012969472148546978, 'rf_n_estimators': 286, 'rf_max_depth': 64, 'rf_min_samples_split': 3, 'gb_learning_rate': 0.05302021110034146, 'gb_n_estimators': 290, 'gb_subsample': 0.8151560975025802}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:48:20,357] Trial 26 finished with value: 0.8242862394114437 and parameters: {'svc_rbf_c': 55.0556685747084, 'svc_rbf_gamma': 0.005742822521322878, 'rf_n_estimators': 286, 'rf_max_depth': 65, 'rf_min_samples_split': 3, 'gb_learning_rate': 0.029660980296175053, 'gb_n_estimators': 296, 'gb_subsample': 0.825209694560315}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:48:55,226] Trial 27 finished with value: 0.8157715971885181 and parameters: {'svc_rbf_c': 0.8317791332211796, 'svc_rbf_gamma': 0.011813193396969303, 'rf_n_estimators': 207, 'rf_max_depth': 53, 'rf_min_samples_split': 3, 'gb_learning_rate': 0.049336214384222345, 'gb_n_estimators': 226, 'gb_subsample': 0.8197203047471026}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:49:33,330] Trial 28 finished with value: 0.8220538492875912 and parameters: {'svc_rbf_c': 116.47716695186405, 'svc_rbf_gamma': 0.011060577667666755, 'rf_n_estimators': 291, 'rf_max_depth': 80, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.023970444464756734, 'gb_n_estimators': 292, 'gb_subsample': 0.6908867755625774}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:50:26,723] Trial 29 finished with value: 0.8269302424179513 and parameters: {'svc_rbf_c': 194.91094102506838, 'svc_rbf_gamma': 0.34678246420223097, 'rf_n_estimators': 262, 'rf_max_depth': 66, 'rf_min_samples_split': 2, 'gb_learning_rate': 0.02260611917903425, 'gb_n_estimators': 362, 'gb_subsample': 0.7809390017576014}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:51:21,250] Trial 30 finished with value: 0.8295801892877956 and parameters: {'svc_rbf_c': 56.607582068500854, 'svc_rbf_gamma': 0.07277749475923338, 'rf_n_estimators': 317, 'rf_max_depth': 70, 'rf_min_samples_split': 4, 'gb_learning_rate': 0.03423840202119039, 'gb_n_estimators': 322, 'gb_subsample': 0.9033510750109185}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:51:43,326] Trial 31 finished with value: 0.8238254892447028 and parameters: {'svc_rbf_c': 86.13361507087268, 'svc_rbf_gamma': 0.16123625193727165, 'rf_n_estimators': 231, 'rf_max_depth': 59, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.06974064651387027, 'gb_n_estimators': 136, 'gb_subsample': 0.7666688644513511}. Best is trial 11 with value: 0.8318486783410695.
# [I 2026-05-21 12:52:11,739] Trial 32 finished with value: 0.8322573758438624 and parameters: {'svc_rbf_c': 46.41334727799991, 'svc_rbf_gamma': 0.06975535323026172, 'rf_n_estimators': 339, 'rf_max_depth': 62, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.08876292581452035, 'gb_n_estimators': 184, 'gb_subsample': 0.7572731215737645}. Best is trial 32 with value: 0.8322573758438624.
# [I 2026-05-21 12:52:42,387] Trial 33 finished with value: 0.834958933206572 and parameters: {'svc_rbf_c': 30.38192897953169, 'svc_rbf_gamma': 0.07511129081738645, 'rf_n_estimators': 246, 'rf_max_depth': 65, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.09655667659107364, 'gb_n_estimators': 192, 'gb_subsample': 0.8156644924635846}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:53:08,883] Trial 34 finished with value: 0.8280281716617854 and parameters: {'svc_rbf_c': 13.331521126821182, 'svc_rbf_gamma': 0.01652349106124832, 'rf_n_estimators': 245, 'rf_max_depth': 73, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.10147997899828037, 'gb_n_estimators': 192, 'gb_subsample': 0.7157772793786408}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:54:03,636] Trial 35 finished with value: 0.8305392393147623 and parameters: {'svc_rbf_c': 31.83358256566933, 'svc_rbf_gamma': 0.007051829608116099, 'rf_n_estimators': 323, 'rf_max_depth': 68, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.06124774292230129, 'gb_n_estimators': 398, 'gb_subsample': 0.7530712083333844}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:54:39,785] Trial 36 finished with value: 0.8307293788766272 and parameters: {'svc_rbf_c': 20.545986416865865, 'svc_rbf_gamma': 0.06509968488515262, 'rf_n_estimators': 262, 'rf_max_depth': 76, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.08727866078756881, 'gb_n_estimators': 232, 'gb_subsample': 0.8063044578749434}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:55:12,414] Trial 37 finished with value: 0.8329564062017082 and parameters: {'svc_rbf_c': 32.67605104507512, 'svc_rbf_gamma': 0.018881399315095915, 'rf_n_estimators': 350, 'rf_max_depth': 51, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.09768414547708759, 'gb_n_estimators': 194, 'gb_subsample': 0.8375789216491606}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:55:39,918] Trial 38 finished with value: 0.8207838868402962 and parameters: {'svc_rbf_c': 26.541505691598854, 'svc_rbf_gamma': 0.0028024883162191296, 'rf_n_estimators': 348, 'rf_max_depth': 52, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.09676252824656814, 'gb_n_estimators': 161, 'gb_subsample': 0.8502323595891589}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:56:13,709] Trial 39 finished with value: 0.8302410503993182 and parameters: {'svc_rbf_c': 10.90066598688956, 'svc_rbf_gamma': 0.059843891242247683, 'rf_n_estimators': 352, 'rf_max_depth': 39, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.16412513370206847, 'gb_n_estimators': 193, 'gb_subsample': 0.8831685599540016}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:56:44,885] Trial 40 finished with value: 0.8300308505966626 and parameters: {'svc_rbf_c': 5.512385189828999, 'svc_rbf_gamma': 0.02102510598499913, 'rf_n_estimators': 394, 'rf_max_depth': 50, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.10640157852986803, 'gb_n_estimators': 186, 'gb_subsample': 0.8394846361055602}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:57:39,290] Trial 41 finished with value: 0.8309167335014166 and parameters: {'svc_rbf_c': 43.93975874455173, 'svc_rbf_gamma': 0.009041212016587068, 'rf_n_estimators': 237, 'rf_max_depth': 57, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.043981903004107925, 'gb_n_estimators': 374, 'gb_subsample': 0.8018426771148696}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:58:12,936] Trial 42 finished with value: 0.8293046812745928 and parameters: {'svc_rbf_c': 18.52489547128323, 'svc_rbf_gamma': 0.01382571817731281, 'rf_n_estimators': 277, 'rf_max_depth': 68, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.08827306523454953, 'gb_n_estimators': 219, 'gb_subsample': 0.8006456645364657}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:58:43,436] Trial 43 finished with value: 0.8186922796880337 and parameters: {'svc_rbf_c': 0.1813554329511888, 'svc_rbf_gamma': 0.004013348239924363, 'rf_n_estimators': 323, 'rf_max_depth': 62, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.1992813176730299, 'gb_n_estimators': 173, 'gb_subsample': 0.8677864402665407}. Best is trial 33 with value: 0.834958933206572.
# [I 2026-05-21 12:59:18,365] Trial 44 finished with value: 0.8365700860728609 and parameters: {'svc_rbf_c': 35.53564886128139, 'svc_rbf_gamma': 0.0475768828075024, 'rf_n_estimators': 431, 'rf_max_depth': 72, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.06600259640694434, 'gb_n_estimators': 244, 'gb_subsample': 0.715690145641629}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 12:59:53,401] Trial 45 finished with value: 0.8357242067188162 and parameters: {'svc_rbf_c': 3.1868593766268702, 'svc_rbf_gamma': 0.050855427065868174, 'rf_n_estimators': 424, 'rf_max_depth': 72, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.12049820458439434, 'gb_n_estimators': 243, 'gb_subsample': 0.7003481592272831}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:00:27,864] Trial 46 finished with value: 0.8295273459125331 and parameters: {'svc_rbf_c': 3.6665534509783546, 'svc_rbf_gamma': 0.20137774392741578, 'rf_n_estimators': 442, 'rf_max_depth': 74, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.11436086200471066, 'gb_n_estimators': 241, 'gb_subsample': 0.6818774009512141}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:00:57,391] Trial 47 finished with value: 0.8279914535751964 and parameters: {'svc_rbf_c': 1.2139296579860284, 'svc_rbf_gamma': 0.04690656916181693, 'rf_n_estimators': 422, 'rf_max_depth': 76, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.137415907228252, 'gb_n_estimators': 203, 'gb_subsample': 0.7017086708367688}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:01:34,244] Trial 48 finished with value: 0.8215307123207568 and parameters: {'svc_rbf_c': 0.5332433131765361, 'svc_rbf_gamma': 0.09249694108870461, 'rf_n_estimators': 485, 'rf_max_depth': 72, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.08150211503439142, 'gb_n_estimators': 247, 'gb_subsample': 0.7242874226221956}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:02:02,805] Trial 49 finished with value: 0.8302730491608016 and parameters: {'svc_rbf_c': 8.420246095812104, 'svc_rbf_gamma': 0.03443516617918469, 'rf_n_estimators': 373, 'rf_max_depth': 44, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.1236316187431435, 'gb_n_estimators': 216, 'gb_subsample': 0.6570225255272932}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:02:29,667] Trial 50 finished with value: 0.8274561302308983 and parameters: {'svc_rbf_c': 36.55671328261365, 'svc_rbf_gamma': 0.29027317106195766, 'rf_n_estimators': 477, 'rf_max_depth': 14, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.16062717590285078, 'gb_n_estimators': 181, 'gb_subsample': 0.6636455663329909}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:02:54,519] Trial 51 finished with value: 0.8289616470248952 and parameters: {'svc_rbf_c': 18.236763254452523, 'svc_rbf_gamma': 0.02381788722290222, 'rf_n_estimators': 519, 'rf_max_depth': 68, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.06449592172476304, 'gb_n_estimators': 163, 'gb_subsample': 0.7056439797718269}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:03:42,110] Trial 52 finished with value: 0.8301036068737528 and parameters: {'svc_rbf_c': 6.7905480907566425, 'svc_rbf_gamma': 0.04685601909570681, 'rf_n_estimators': 687, 'rf_max_depth': 71, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.0786150237182107, 'gb_n_estimators': 310, 'gb_subsample': 0.7574278083354083}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:04:21,909] Trial 53 finished with value: 0.8324238611297927 and parameters: {'svc_rbf_c': 2.9732165229709815, 'svc_rbf_gamma': 0.068661577842034, 'rf_n_estimators': 554, 'rf_max_depth': 77, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.0971961282566061, 'gb_n_estimators': 241, 'gb_subsample': 0.787715154649382}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:04:56,725] Trial 54 finished with value: 0.8310562996685998 and parameters: {'svc_rbf_c': 2.5321981277255845, 'svc_rbf_gamma': 0.07251044085974136, 'rf_n_estimators': 569, 'rf_max_depth': 76, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.11044695745569602, 'gb_n_estimators': 276, 'gb_subsample': 0.6048864057000767}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:05:33,296] Trial 55 finished with value: 0.8307990253144619 and parameters: {'svc_rbf_c': 1.4997334146403338, 'svc_rbf_gamma': 0.10596232767325682, 'rf_n_estimators': 546, 'rf_max_depth': 80, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.0948433304230816, 'gb_n_estimators': 238, 'gb_subsample': 0.7326793122061289}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:06:12,523] Trial 56 finished with value: 0.8312850688863751 and parameters: {'svc_rbf_c': 24.914620951049272, 'svc_rbf_gamma': 0.033724961905565176, 'rf_n_estimators': 435, 'rf_max_depth': 43, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.13137914748003912, 'gb_n_estimators': 255, 'gb_subsample': 0.7775136981739129}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:06:46,108] Trial 57 finished with value: 0.8319084017331636 and parameters: {'svc_rbf_c': 4.026931927951229, 'svc_rbf_gamma': 0.05827617734801157, 'rf_n_estimators': 467, 'rf_max_depth': 74, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.15788111228721802, 'gb_n_estimators': 222, 'gb_subsample': 0.7378036190403359}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:07:19,699] Trial 58 finished with value: 0.8324030798234902 and parameters: {'svc_rbf_c': 114.11511767499177, 'svc_rbf_gamma': 0.18051782892578241, 'rf_n_estimators': 514, 'rf_max_depth': 54, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.11618538919796859, 'gb_n_estimators': 199, 'gb_subsample': 0.7891457144094957}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:07:56,403] Trial 59 finished with value: 0.8328717655311375 and parameters: {'svc_rbf_c': 138.42971409498492, 'svc_rbf_gamma': 0.18530792069493784, 'rf_n_estimators': 517, 'rf_max_depth': 55, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.1171246187278884, 'gb_n_estimators': 208, 'gb_subsample': 0.8368043432818278}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:08:33,857] Trial 60 finished with value: 0.8261706698267329 and parameters: {'svc_rbf_c': 130.4622992197044, 'svc_rbf_gamma': 0.38080523696320173, 'rf_n_estimators': 500, 'rf_max_depth': 48, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.06616669289084373, 'gb_n_estimators': 210, 'gb_subsample': 0.8441753748675681}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:09:11,094] Trial 61 finished with value: 0.8326550917596925 and parameters: {'svc_rbf_c': 140.4607282672387, 'svc_rbf_gamma': 0.1908330097506281, 'rf_n_estimators': 550, 'rf_max_depth': 59, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.12085464181290209, 'gb_n_estimators': 203, 'gb_subsample': 0.8639235916040381}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:09:54,567] Trial 62 finished with value: 0.8256734659734474 and parameters: {'svc_rbf_c': 0.47658026425560773, 'svc_rbf_gamma': 0.21441663436928143, 'rf_n_estimators': 547, 'rf_max_depth': 55, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.13461364828347358, 'gb_n_estimators': 245, 'gb_subsample': 0.8656982523113684}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:10:40,381] Trial 63 finished with value: 0.8223978594413368 and parameters: {'svc_rbf_c': 153.5707029237871, 'svc_rbf_gamma': 0.9176888262450751, 'rf_n_estimators': 545, 'rf_max_depth': 59, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.17752763705518967, 'gb_n_estimators': 267, 'gb_subsample': 0.8340861594589505}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:11:23,003] Trial 64 finished with value: 0.8249591487099003 and parameters: {'svc_rbf_c': 69.87560485882699, 'svc_rbf_gamma': 0.5786274050011995, 'rf_n_estimators': 505, 'rf_max_depth': 66, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.0779833174020599, 'gb_n_estimators': 228, 'gb_subsample': 0.8990115056427905}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:12:02,013] Trial 65 finished with value: 0.8341375331097152 and parameters: {'svc_rbf_c': 181.010851477976, 'svc_rbf_gamma': 0.12744321646869794, 'rf_n_estimators': 565, 'rf_max_depth': 78, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.10453131967358381, 'gb_n_estimators': 215, 'gb_subsample': 0.8645721421980147}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:12:41,874] Trial 66 finished with value: 0.8305349650042158 and parameters: {'svc_rbf_c': 140.81921448668317, 'svc_rbf_gamma': 0.13753108998674152, 'rf_n_estimators': 630, 'rf_max_depth': 51, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.1511290409199547, 'gb_n_estimators': 214, 'gb_subsample': 0.873719061069875}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:13:18,751] Trial 67 finished with value: 0.8306809418855147 and parameters: {'svc_rbf_c': 171.35124572524256, 'svc_rbf_gamma': 0.09374823635286504, 'rf_n_estimators': 460, 'rf_max_depth': 60, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.12141057829221133, 'gb_n_estimators': 197, 'gb_subsample': 0.9017825739709665}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:13:52,499] Trial 68 finished with value: 0.8305298725667013 and parameters: {'svc_rbf_c': 56.34469464127886, 'svc_rbf_gamma': 0.24598027106462464, 'rf_n_estimators': 575, 'rf_max_depth': 56, 'rf_min_samples_split': 4, 'gb_learning_rate': 0.105299916624922, 'gb_n_estimators': 157, 'gb_subsample': 0.9536492887120351}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:14:25,651] Trial 69 finished with value: 0.8072050010167562 and parameters: {'svc_rbf_c': 85.82075042306228, 'svc_rbf_gamma': 0.4600446162382452, 'rf_n_estimators': 593, 'rf_max_depth': 78, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.01165414390291869, 'gb_n_estimators': 174, 'gb_subsample': 0.8584397219019808}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:15:07,610] Trial 70 finished with value: 0.8315535060582476 and parameters: {'svc_rbf_c': 116.11664444299022, 'svc_rbf_gamma': 0.12776108245636586, 'rf_n_estimators': 412, 'rf_max_depth': 70, 'rf_min_samples_split': 5, 'gb_learning_rate': 0.057210878616443736, 'gb_n_estimators': 233, 'gb_subsample': 0.8927652816708952}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:15:49,402] Trial 71 finished with value: 0.831377069787577 and parameters: {'svc_rbf_c': 13.267386131676709, 'svc_rbf_gamma': 0.028889987478000888, 'rf_n_estimators': 533, 'rf_max_depth': 77, 'rf_min_samples_split': 6, 'gb_learning_rate': 0.0939051617191991, 'gb_n_estimators': 257, 'gb_subsample': 0.8170993899796151}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:16:26,231] Trial 72 finished with value: 0.8329749727705279 and parameters: {'svc_rbf_c': 35.28715228561941, 'svc_rbf_gamma': 0.04793010295376539, 'rf_n_estimators': 553, 'rf_max_depth': 73, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.10138474913163542, 'gb_n_estimators': 210, 'gb_subsample': 0.8471713928955744}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:16:59,365] Trial 73 finished with value: 0.8334278091229622 and parameters: {'svc_rbf_c': 190.67662144819025, 'svc_rbf_gamma': 0.05068007617707885, 'rf_n_estimators': 532, 'rf_max_depth': 64, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.14053766264142045, 'gb_n_estimators': 190, 'gb_subsample': 0.8304388847956329}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:17:26,365] Trial 74 finished with value: 0.8320329268161788 and parameters: {'svc_rbf_c': 33.03504600340871, 'svc_rbf_gamma': 0.04424727604707015, 'rf_n_estimators': 496, 'rf_max_depth': 72, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.1465886935471691, 'gb_n_estimators': 151, 'gb_subsample': 0.8279317735388458}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:17:58,730] Trial 75 finished with value: 0.8298914303744489 and parameters: {'svc_rbf_c': 53.694641172740575, 'svc_rbf_gamma': 0.018475146397696193, 'rf_n_estimators': 393, 'rf_max_depth': 64, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.1963084007416992, 'gb_n_estimators': 190, 'gb_subsample': 0.8492217188437942}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:18:35,746] Trial 76 finished with value: 0.8351651048561893 and parameters: {'svc_rbf_c': 98.4038258444853, 'svc_rbf_gamma': 0.05169604905594927, 'rf_n_estimators': 564, 'rf_max_depth': 67, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.08116578919364825, 'gb_n_estimators': 221, 'gb_subsample': 0.8094059283733979}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:19:13,826] Trial 77 finished with value: 0.8137964346486911 and parameters: {'svc_rbf_c': 0.06670092767560803, 'svc_rbf_gamma': 0.05268389115090077, 'rf_n_estimators': 613, 'rf_max_depth': 70, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.08287424189866502, 'gb_n_estimators': 224, 'gb_subsample': 0.8131790395807738}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:19:44,869] Trial 78 finished with value: 0.8320776569173849 and parameters: {'svc_rbf_c': 196.58977354592315, 'svc_rbf_gamma': 0.035139486515685284, 'rf_n_estimators': 561, 'rf_max_depth': 66, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.07628567505336714, 'gb_n_estimators': 168, 'gb_subsample': 0.8748973101591818}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:20:19,472] Trial 79 finished with value: 0.811561809580656 and parameters: {'svc_rbf_c': 91.38618700722662, 'svc_rbf_gamma': 0.0003846901160284175, 'rf_n_estimators': 582, 'rf_max_depth': 24, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.06781620154874506, 'gb_n_estimators': 183, 'gb_subsample': 0.9162594755996156}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:20:57,203] Trial 80 finished with value: 0.8309303148300725 and parameters: {'svc_rbf_c': 41.42891856207984, 'svc_rbf_gamma': 0.02804469974184817, 'rf_n_estimators': 634, 'rf_max_depth': 73, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.10638464161282887, 'gb_n_estimators': 216, 'gb_subsample': 0.8248742607336682}. Best is trial 44 with value: 0.8365700860728609.
# [I 2026-05-21 13:21:34,838] Trial 81 finished with value: 0.8368509972849559 and parameters: {'svc_rbf_c': 68.25350463775932, 'svc_rbf_gamma': 0.10649020878581128, 'rf_n_estimators': 602, 'rf_max_depth': 69, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.13325470853637358, 'gb_n_estimators': 212, 'gb_subsample': 0.8407412028680834}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:22:09,061] Trial 82 finished with value: 0.8304783950529148 and parameters: {'svc_rbf_c': 62.38205646086745, 'svc_rbf_gamma': 0.0991869580141925, 'rf_n_estimators': 597, 'rf_max_depth': 67, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.17436285786234218, 'gb_n_estimators': 198, 'gb_subsample': 0.805998926935437}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:22:48,198] Trial 83 finished with value: 0.831091061648138 and parameters: {'svc_rbf_c': 28.10155723177922, 'svc_rbf_gamma': 0.0794641419747153, 'rf_n_estimators': 373, 'rf_max_depth': 69, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.13853715646798362, 'gb_n_estimators': 233, 'gb_subsample': 0.8511336151335199}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:23:25,498] Trial 84 finished with value: 0.8322874813079711 and parameters: {'svc_rbf_c': 72.34519780016123, 'svc_rbf_gamma': 0.04301665224844334, 'rf_n_estimators': 662, 'rf_max_depth': 63, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.09008064769473138, 'gb_n_estimators': 208, 'gb_subsample': 0.8403956085223186}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:24:05,893] Trial 85 finished with value: 0.8273196187987161 and parameters: {'svc_rbf_c': 106.37271515143897, 'svc_rbf_gamma': 0.008740454971137701, 'rf_n_estimators': 432, 'rf_max_depth': 75, 'rf_min_samples_split': 10, 'gb_learning_rate': 0.09937632733789463, 'gb_n_estimators': 250, 'gb_subsample': 0.8281307683373851}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:24:36,331] Trial 86 finished with value: 0.8324386600246944 and parameters: {'svc_rbf_c': 42.5948316760229, 'svc_rbf_gamma': 0.05789050697220275, 'rf_n_estimators': 570, 'rf_max_depth': 72, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.1287697221956875, 'gb_n_estimators': 178, 'gb_subsample': 0.7964031654462381}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:25:12,537] Trial 87 finished with value: 0.8266406794937802 and parameters: {'svc_rbf_c': 16.418573449263317, 'svc_rbf_gamma': 0.014363775002430848, 'rf_n_estimators': 526, 'rf_max_depth': 65, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.08613623635459092, 'gb_n_estimators': 221, 'gb_subsample': 0.8129991110702764}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:25:49,096] Trial 88 finished with value: 0.8303970057567812 and parameters: {'svc_rbf_c': 22.421674981180267, 'svc_rbf_gamma': 0.022174780177206515, 'rf_n_estimators': 603, 'rf_max_depth': 78, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.07310429028132145, 'gb_n_estimators': 190, 'gb_subsample': 0.8867402217806941}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:26:24,722] Trial 89 finished with value: 0.8301560119546694 and parameters: {'svc_rbf_c': 9.113103073082307, 'svc_rbf_gamma': 0.08388399869187609, 'rf_n_estimators': 587, 'rf_max_depth': 68, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.10753502675202915, 'gb_n_estimators': 213, 'gb_subsample': 0.7720109372977844}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:27:04,655] Trial 90 finished with value: 0.8341794443402596 and parameters: {'svc_rbf_c': 49.91465535357917, 'svc_rbf_gamma': 0.12201682173557976, 'rf_n_estimators': 536, 'rf_max_depth': 71, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.046859805086203736, 'gb_n_estimators': 227, 'gb_subsample': 0.853034283247565}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:27:46,202] Trial 91 finished with value: 0.826956268761086 and parameters: {'svc_rbf_c': 82.21798575233124, 'svc_rbf_gamma': 0.11974310665557658, 'rf_n_estimators': 533, 'rf_max_depth': 75, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.03431870069573703, 'gb_n_estimators': 236, 'gb_subsample': 0.8508172957352726}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:28:25,578] Trial 92 finished with value: 0.8327048871053627 and parameters: {'svc_rbf_c': 35.58929733492029, 'svc_rbf_gamma': 0.03612043391520021, 'rf_n_estimators': 560, 'rf_max_depth': 73, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.05567814050971008, 'gb_n_estimators': 224, 'gb_subsample': 0.862203756482462}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:29:03,654] Trial 93 finished with value: 0.8300719087610288 and parameters: {'svc_rbf_c': 48.3934322733398, 'svc_rbf_gamma': 0.15303594087147868, 'rf_n_estimators': 307, 'rf_max_depth': 70, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.048487394279476466, 'gb_n_estimators': 229, 'gb_subsample': 0.8321100016208132}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:29:41,593] Trial 94 finished with value: 0.8340201120468684 and parameters: {'svc_rbf_c': 66.01607682332254, 'svc_rbf_gamma': 0.10981194083092187, 'rf_n_estimators': 625, 'rf_max_depth': 79, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.06060570773246933, 'gb_n_estimators': 261, 'gb_subsample': 0.6807791971353546}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:30:21,998] Trial 95 finished with value: 0.8325683408682029 and parameters: {'svc_rbf_c': 101.60233100387501, 'svc_rbf_gamma': 0.10521278775943872, 'rf_n_estimators': 627, 'rf_max_depth': 80, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.04930850799846381, 'gb_n_estimators': 282, 'gb_subsample': 0.6735795192640124}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:31:01,630] Trial 96 finished with value: 0.8350395194560204 and parameters: {'svc_rbf_c': 193.486055926155, 'svc_rbf_gamma': 0.07903159360352167, 'rf_n_estimators': 657, 'rf_max_depth': 78, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.060512780506024696, 'gb_n_estimators': 263, 'gb_subsample': 0.6915547106295183}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:31:41,996] Trial 97 finished with value: 0.8315756612541877 and parameters: {'svc_rbf_c': 166.91593579051175, 'svc_rbf_gamma': 0.1175469768500191, 'rf_n_estimators': 668, 'rf_max_depth': 79, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.04498830881688151, 'gb_n_estimators': 278, 'gb_subsample': 0.6894488382128185}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:32:22,031] Trial 98 finished with value: 0.8319009882951146 and parameters: {'svc_rbf_c': 66.62224385030126, 'svc_rbf_gamma': 0.07915632109219818, 'rf_n_estimators': 683, 'rf_max_depth': 78, 'rf_min_samples_split': 8, 'gb_learning_rate': 0.06332460668038269, 'gb_n_estimators': 269, 'gb_subsample': 0.7128629624421663}. Best is trial 81 with value: 0.8368509972849559.
# [I 2026-05-21 13:32:58,826] Trial 99 finished with value: 0.8287129237242601 and parameters: {'svc_rbf_c': 198.8767687061401, 'svc_rbf_gamma': 0.28166411126757523, 'rf_n_estimators': 607, 'rf_max_depth': 67, 'rf_min_samples_split': 9, 'gb_learning_rate': 0.06104761693919552, 'gb_n_estimators': 263, 'gb_subsample': 0.6595502349568856}. Best is trial 81 with value: 0.8368509972849559.
# ==============================
#   MEJORES PARÁMETROS ENCONTRADOS
# ==============================
# {'svc_rbf_c': 68.25350463775932, 'svc_rbf_gamma': 0.10649020878581128, 'rf_n_estimators': 602, 'rf_max_depth': 69, 'rf_min_samples_split': 7, 'gb_learning_rate': 0.13325470853637358, 'gb_n_estimators': 212, 'gb_subsample': 0.8407412028680834}
# VotingClassifier(estimators=[('svm_linear',
#                               SVC(class_weight='balanced', kernel='linear',
#                                   probability=True, random_state=42)),
#                              ('svm_rbf',
#                               SVC(C=68.25350463775932, class_weight='balanced',
#                                   gamma=0.10649020878581128, probability=True,
#                                   random_state=42)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=69,
#                                                      min_samples_split=7,
#                                                      n_estimators=602,
#                                                      random_state=42)),
#                              ('gb',
#                               GradientBoostingClassifier(learning_rate=0.13325470853637358,
#                                                          n_estimators=212,
#                                                          random_state=42,
#                                                          subsample=0.8407412028680834))],
#                  voting='soft', weights=[1, 1, 1, 2])

# %%
# Lista para guardar los resultados de cada modelo que evalúes
resultados_smote = []

def evaluar_y_visualizar(y_test, y_pred, name, classes):
    """
    Calcula métricas clave, imprime el reporte y genera la matriz de confusión.
    """
    # 1. Cálculo de métricas
    acc = accuracy_score(y_test, y_pred)
    macro_f1 = f1_score(y_test, y_pred, average='macro')
    
    # 2. Impresión de resultados
    print(f"--- RESULTADOS: {name} ---")
    print(f"Exactitud (Accuracy): {acc:.4f}")
    print(f"Macro F1-Score: {macro_f1:.4f}\n")
    print("Reporte de Clasificación:")
    print(classification_report(y_test, y_pred, target_names=classes))
    
    # 3. Guardar en lista
    resultados_smote.append({
        'Modelo': name, 
        'Accuracy': round(acc, 4), 
        'Macro F1': round(macro_f1, 4)
    })
    
    # 4. Visualización de Matriz de Confusión
    plt.figure(figsize=(8, 6))
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', 
                xticklabels=classes, yticklabels=classes)
    plt.title(f'Matriz de Confusión (SMOTE) — {name}')
    plt.ylabel('Etiqueta Real')
    plt.xlabel('Etiqueta Predicha')
    plt.show()

evaluar_y_visualizar(y_test, y_pred_opt, "Voting Classifier Final", le.classes_)
# Out:
# --- RESULTADOS: Voting Classifier Final ---
# Exactitud (Accuracy): 0.7435
# Macro F1-Score: 0.7455
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#  Electronica       0.64      0.69      0.66       155
#      Hip-Hop       0.71      0.68      0.69        98
#         Rock       0.69      0.74      0.72        86
#    Vallenato       0.89      0.81      0.85       129
#      clasicc       0.97      0.95      0.96       149
#         jazz       0.85      0.84      0.84       177
#          pop       0.49      0.50      0.50       169
#
#     accuracy                           0.74       963
#    macro avg       0.75      0.74      0.75       963
# weighted avg       0.75      0.74      0.75       963

# %%
"""  
import joblib
import os

joblib.dump(voting_final_opt, '../../reports/models/v1/veles_model.pkl')
joblib.dump(le, '../../reports/models/v1/label_encoder.pkl')

print("Modelo y LabelEncoder guardados exitosamente en la carpeta 'reports/models/v1/'")
"""
# Out:
# Modelo y LabelEncoder guardados exitosamente en la carpeta 'reports/models/v1/'
